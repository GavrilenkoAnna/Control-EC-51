# %% [markdown]
# Имеем датасет состоящий из 5 переменных и 50 записей.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Сперва подключаю все необходимые для работы и предустановленные библиотеки, загружаю подготовленный в Excel файл.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
df = pd.read_csv('zad1.csv', sep=',')

# %% [markdown]
# Для наглядности выведем импортрованнные данные на экран; убедимся, что всё загрузилось должным образом.

# %%
df
# Out:
#         Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %% [markdown]
# Выведем статистику по числовым переменным, где сразу увидим, что в переменных отсутствуют пропущенные значения.

# %%
df.describe()
# Out:
#                Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# Проведем проверку типов данных по переменным и выявим соответствие.

# %%
df.dtypes
# Out:
# Spend              float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %% [markdown]
# Следующим этапом подготовки данных будет проверка на наличие пропущенных значений.
# Выведем общее количество и процент пропусков по переменным. Как было указано ранее, они отсутствуют.

# %%
# Cheking Missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                  Total  Percent
# Profit               0      0.0
# State                0      0.0
# Marketing Spend      0      0.0
# Administration       0      0.0
# Spend                0      0.0

# %%
df.describe()
# Out:
#                Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# Осуществим работы с выбросами в числовых переменных: для этого запишем функцию для поиска и замены данных, выходящих за пределы 3 сигма.

# %%
# Function Outliers
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %% [markdown]
# Запишем в наш датафрейм уже очищенные от  выбросов переменные и повторно выведем статистику.
# В результате выполнения очистки можно наблядать, что показатели максимального, минимального, среднего значений, а также стандартного отклонения не изменились и соответствуют нормальному распределению, что говорит об отсутствии выбросов.

# %%
# Outliers
df = outliers(df)
df.describe()
# Out:
#                Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# Построим графики распределения функций, которые говорят о нормальности распределения.

# %%
# Features distribution
import seaborn as sns
sns.set()
sns.pairplot(df, size = 2.5)
plt.show();
# Out:
# C:\Users\User\anaconda3\envs\tensorflow_env\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Следующий шаг- кодирование категориальных переменных.
# После выполнения представленной функции, записываем закодированные данные в датафрейм и выводим результат.

# %%
# Function Encoding
def encoding_char(x):
    char_var = list(set(x.columns) - set(x._get_numeric_data().columns))
    for col_names in char_var:
        f = pd.factorize(x[col_names])
        x[col_names] = pd.factorize(x[col_names])[0]
    return(x)

# %%
# Encoding categorical data
df = encoding_char(df)

# %%
df
# Out:
#         Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      0  192261.83
# 1   162597.70       151377.59        443898.53      1  191792.06
# 2   153441.51       101145.55        407934.54      2  191050.39
# 3   144372.41       118671.85        383199.62      0  182901.99
# 4   142107.34        91391.77        366168.42      2  166187.94
# 5   131876.90        99814.71        362861.36      0  156991.12
# 6   134615.46       147198.87        127716.82      1  156122.51
# 7   130298.13       145530.06        323876.68      2  155752.60
# 8   120542.52       148718.95        311613.29      0  152211.77
# 9   123334.88       108679.17        304981.62      1  149759.96
# 10  101913.08       110594.11        229160.95      2  146121.95
# 11  100671.96        91790.61        249744.55      1  144259.40
# 12   93863.75       127320.38        249839.44      2  141585.52
# 13   91992.39       135495.07        252664.93      1  134307.35
# 14  119943.24       156547.42        256512.92      2  132602.65
# 15  114523.61       122616.84        261776.23      0  129917.04
# 16   78013.11       121597.55        264346.06      1  126992.93
# 17   94657.16       145077.58        282574.31      0  125370.37
# 18   91749.16       114175.79        294919.57      2  124266.90
# 19   86419.70       153514.11             0.00      0  122776.86
# 20   76253.86       113867.30        298664.47      1  118474.03
# 21   78389.47       153773.43        299737.29      0  111313.02
# 22   73994.56       122782.75        303319.26      2  110352.25
# 23   67532.53       105751.03        304768.73      2  108733.99
# 24   77044.01        99281.34        140574.81      0  108552.04
# 25   64664.71       139553.16        137962.62      1  107404.34
# 26   75328.87       144135.98        134050.07      2  105733.54
# 27   72107.60       127864.55        353183.81      0  105008.31
# 28   66051.52       182645.56        118148.20      2  103282.38
# 29   65605.48       153032.06        107138.38      0  101004.64
# 30   61994.48       115641.28         91131.24      2   99937.59
# 31   61136.38       152701.92         88218.23      0   97483.56
# 32   63408.86       129219.61         46085.25      1   97427.84
# 33   55493.95       103057.49        214634.81      2   96778.92
# 34   46426.07       157693.92        210797.67      1   96712.80
# 35   46014.02        85047.44        205517.64      0   96479.51
# 36   28663.76       127056.21        201126.82      2   90708.19
# 37   44069.95        51283.14        197029.42      1   89949.14
# 38   20229.59        65947.93        185265.10      0   81229.06
# 39   38558.51        82982.09        174999.30      1   81005.76
# 40   28754.33       118546.05        172795.67      1   78239.91
# 41   27892.92        84710.77        164470.71      2   77798.83
# 42   23640.93        96189.63        148001.11      1   71498.49
# 43   15505.73       127382.30         35534.17      0   69758.98
# 44   22177.74       154806.14         28334.72      1   65200.33
# 45    1000.23       124153.04          1903.93      0   64926.08
# 46    1315.46       115816.21        297114.46      2   49490.75
# 47       0.00       135426.92             0.00      1   42559.73
# 48     542.05        51743.15             0.00      0   35673.41
# 49       0.00       116983.80         45173.06      1   14681.40

# %% [markdown]
# Имеем подготовленный набор данных, который можно далее использовать для моделирования.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Следующий этап - моделирование.
# Начнем с построения многофакторной линейной регрессии. Выведем корреляционную матрицу для визуализации и выявления наиболее значимых факторов, которые необходимо будет включить в модель. Как можно определить изначально, большее влияние имеет переменная Spend и Marketing Spend.

# %%
# Cheking correlations
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# Поделим выборку на обучающую и тестовую (20%), запишем разделенные данные.

# %%
# Splitting the dataset into the Training set and Test set
X = df.iloc[:, :-1].values
y = df.iloc[:, 4].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# Построим модель многофакторной регрессии от всех переменных, включив константу, и выведем статистику по ней.

# %%
# Multiple Linear Regression, checking p-values
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
X = sm.add_constant(X_train)
mr1 = sm.OLS(y_train, X).fit()
#mr1.pvalues
mr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     133.7
# Date:                Mon, 21 Dec 2020   Prob (F-statistic):           1.08e-20
# Time:                        12:02:07   Log-Likelihood:                -423.98
# No. Observations:                  40   AIC:                             858.0
# Df Residuals:                      35   BIC:                             866.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.925e+04   8266.208      5.958      0.000    3.25e+04     6.6e+04
# x1             0.8059      0.058     13.978      0.000       0.689       0.923
# x2            -0.0179      0.064     -0.282      0.780      -0.147       0.111
# x3             0.0228      0.021      1.071      0.291      -0.020       0.066
# x4           741.7033   1983.728      0.374      0.711   -3285.479    4768.885
# ==============================================================================
# Omnibus:                       12.199   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.692
# Skew:                          -0.987   Prob(JB):                      0.00106
# Kurtosis:                       5.079   Cond. No.                     1.43e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Как показывает статистика,значимыми являются 1 и 3 переменные модели. Коэффициент детерминации  высокий, модель значимая.
#
# Cтроим оптимальную модель, включая значимые факторы.

# %%
X_train = X_train[:, [0, 2]]
X_test = X_test[:, [0, 2]]

# %%
# Fitting Optimized Multiple Regression to the Training set
from sklearn.linear_model import LinearRegression
mr = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# Получаем коэффициенты регрессии:

# %%
# Getting parameters
mr.coef_, mr.intercept_
# Out:
# (array([0.79827194, 0.02581271]), 47662.77046436914)

# %% [markdown]
# Строим прогноз на тестовых значениях:

# %%
# Predicting the Test set results
y_pred = mr.predict(X_test)

# %% [markdown]
# Вычисляем коэффициент детерминации, видим, что на тестовых значениях он немного выше.

# %%
# Coefficient of determination R^2
mr.score(X_train, y_train), mr.score(X_test, y_test)
# Out:
# (0.9382176532996815, 0.9909864896179558)

# %% [markdown]
# Находим среднеквадратическое отклонение (т.к. число слишком большое, извлекаем корень), которое на тестовых значениях он ниже.

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
import math
math.sqrt(mean_squared_error(y_train, mr.predict(X_train))), math.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# (9735.044340220777, 4043.76416920085)

# %% [markdown]
# Строим график по наиболее значимой переменной для визуализации результата. Видим, что предсказание работает не идеально, однако имеет свою точность.

# %%
# Visualising the Test set results
plt.scatter(X_test[:,0], y_test, color = 'red')
plt.plot(X_test[:,0], mr.predict(X_test), 'bo')
plt.title('Price vs Power (Test set)')
plt.xlabel('Power')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Итак, мы получили базовую модель, от которой мы будем отталкиваться и ориентирваться в ходе посроения модели нейроной сети.

# %% [markdown]
# # Regression Neural Network

# %% [markdown]
# Наконец переходим к моделированию нейронной сети.
#
# Для начала произведем шкалирование данных, использя выборку train оценим параметры, затем преобразуем обучающую и тестовую выборки.

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler().fit(X_train)
X_train = sc_X.transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler().fit(np.array([[i] for i in y_train]))
y_train = sc_y.transform(np.array([[i] for i in y_train]))
y_test = sc_y.transform(np.array([[i] for i in y_test]))

# %% [markdown]
# Подключим библиотеки, необходимые для работы с нейронными сетями.

# %%
# Install Tensorflow
# Install Keras
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Создаем последовательную нейронную сеть: Добавляем к ней слои, размерность входного слоя равна 8 (в соответствии с переменными предыдущей модели), число нейронов на выходном слое задаем равным 16, так как модель расширяющаяся, функция активации на первом слое-гиперболический тангенс. На втором слое количество нейронов оставляем равным 16, та же функция активации. На последнем слое используем линейную функцию активации.

# %%
# Initialising the ANN
rnn = Sequential()

# Adding the input layer and the first hidden layer
rnn.add(Dense(output_dim = 3, activation = 'tanh', input_dim = 2))

# Adding the second hidden layer
rnn.add(Dense(output_dim = 2, activation = 'tanh'))

# Adding the output layer
rnn.add(Dense(output_dim = 1, activation = 'linear'))

# Compiling the ANN
rnn.compile(optimizer='adam', loss='mean_squared_error', metrics = ['accuracy'])
# Out:
# C:\Users\User\anaconda3\envs\tensorflow_env\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="tanh", input_dim=2, units=3)`
#   """
# C:\Users\User\anaconda3\envs\tensorflow_env\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="tanh", units=2)`
#
# C:\Users\User\anaconda3\envs\tensorflow_env\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="linear", units=1)`
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# Обучаем модель партиями по 8 объектов в течении 100 эпох.

# %%
# Fitting the ANN to the Training set
rnn.fit(X_train, y_train, batch_size = 8, nb_epoch = 80)
# Out:
# C:\Users\User\anaconda3\envs\tensorflow_env\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/80
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7789 - accuracy: 0.0000e+00
# Epoch 2/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.7519 - accuracy: 0.0000e+00
# Epoch 3/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.7279 - accuracy: 0.0000e+00
# Epoch 4/80
# 40/40 [==============================] - 0s 550us/step - loss: 0.7037 - accuracy: 0.0000e+00
# Epoch 5/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.6808 - accuracy: 0.0000e+00
# Epoch 6/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.6571 - accuracy: 0.0000e+00
# Epoch 7/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.6362 - accuracy: 0.0000e+00
# Epoch 8/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.6136 - accuracy: 0.0000e+00
# Epoch 9/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.5924 - accuracy: 0.0000e+00
# Epoch 10/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.5738 - accuracy: 0.0000e+00
# Epoch 11/80
# 40/40 [==============================] - 0s 525us/step - loss: 0.5504 - accuracy: 0.0000e+00
# Epoch 12/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.5316 - accuracy: 0.0000e+00
# Epoch 13/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.5143 - accuracy: 0.0000e+00
# Epoch 14/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.4931 - accuracy: 0.0000e+00
# Epoch 15/80
# 40/40 [==============================] - 0s 325us/step - loss: 0.4776 - accuracy: 0.0000e+00
# Epoch 16/80
# 40/40 [==============================] - 0s 525us/step - loss: 0.4590 - accuracy: 0.0000e+00
# Epoch 17/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.4428 - accuracy: 0.0000e+00
# Epoch 18/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.4255 - accuracy: 0.0000e+00
# Epoch 19/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.4091 - accuracy: 0.0000e+00
# Epoch 20/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.3944 - accuracy: 0.0000e+00
# Epoch 21/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.3815 - accuracy: 0.0000e+00
# Epoch 22/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.3662 - accuracy: 0.0000e+00
# Epoch 23/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.3511 - accuracy: 0.0000e+00
# Epoch 24/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.3401 - accuracy: 0.0000e+00
# Epoch 25/80
# 40/40 [==============================] - 0s 525us/step - loss: 0.3265 - accuracy: 0.0000e+00
# Epoch 26/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.3144 - accuracy: 0.0000e+00
# Epoch 27/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.3036 - accuracy: 0.0000e+00
# Epoch 28/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.2912 - accuracy: 0.0000e+00
# Epoch 29/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.2806 - accuracy: 0.0000e+00
# Epoch 30/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.2712 - accuracy: 0.0000e+00
# Epoch 31/80
# 40/40 [==============================] - 0s 500us/step - loss: 0.2628 - accuracy: 0.0000e+00
# Epoch 32/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.2520 - accuracy: 0.0000e+00
# Epoch 33/80
# 40/40 [==============================] - 0s 425us/step - loss: 0.2434 - accuracy: 0.0000e+00
# Epoch 34/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.2361 - accuracy: 0.0000e+00
# Epoch 35/80
# 40/40 [==============================] - 0s 425us/step - loss: 0.2277 - accuracy: 0.0000e+00
# Epoch 36/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.2208 - accuracy: 0.0000e+00
# Epoch 37/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.2125 - accuracy: 0.0000e+00
# Epoch 38/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.2064 - accuracy: 0.0000e+00
# Epoch 39/80
# 40/40 [==============================] - 0s 325us/step - loss: 0.2011 - accuracy: 0.0000e+00
# Epoch 40/80
# 40/40 [==============================] - 0s 525us/step - loss: 0.1955 - accuracy: 0.0000e+00
# Epoch 41/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1908 - accuracy: 0.0000e+00
# Epoch 42/80
# 40/40 [==============================] - 0s 425us/step - loss: 0.1850 - accuracy: 0.0000e+00
# Epoch 43/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1798 - accuracy: 0.0000e+00
# Epoch 44/80
# 40/40 [==============================] - 0s 325us/step - loss: 0.1764 - accuracy: 0.0000e+00
# Epoch 45/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1716 - accuracy: 0.0000e+00
# Epoch 46/80
# 40/40 [==============================] - 0s 325us/step - loss: 0.1685 - accuracy: 0.0000e+00
# Epoch 47/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1651 - accuracy: 0.0000e+00
# Epoch 48/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.1620 - accuracy: 0.0000e+00
# Epoch 49/80
# 40/40 [==============================] - 0s 325us/step - loss: 0.1586 - accuracy: 0.0000e+00
# Epoch 50/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1561 - accuracy: 0.0000e+00
# Epoch 51/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1538 - accuracy: 0.0000e+00
# Epoch 52/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.1512 - accuracy: 0.0000e+00
# Epoch 53/80
# 40/40 [==============================] - 0s 525us/step - loss: 0.1495 - accuracy: 0.0000e+00
# Epoch 54/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1472 - accuracy: 0.0000e+00
# Epoch 55/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1454 - accuracy: 0.0000e+00
# Epoch 56/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.1438 - accuracy: 0.0000e+00
# Epoch 57/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1422 - accuracy: 0.0000e+00
# Epoch 58/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1404 - accuracy: 0.0000e+00
# Epoch 59/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.1393 - accuracy: 0.0000e+00
# Epoch 60/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.1381 - accuracy: 0.0000e+00
# Epoch 61/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1367 - accuracy: 0.0000e+00
# Epoch 62/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1360 - accuracy: 0.0000e+00
# Epoch 63/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1344 - accuracy: 0.0000e+00
# Epoch 64/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1337 - accuracy: 0.0000e+00
# Epoch 65/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.1326 - accuracy: 0.0000e+00
# Epoch 66/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.1318 - accuracy: 0.0000e+00
# Epoch 67/80
# 40/40 [==============================] - 0s 425us/step - loss: 0.1311 - accuracy: 0.0000e+00
# Epoch 68/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.1303 - accuracy: 0.0000e+00
# Epoch 69/80
# 40/40 [==============================] - 0s 325us/step - loss: 0.1293 - accuracy: 0.0000e+00
# Epoch 70/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1287 - accuracy: 0.0000e+00
# Epoch 71/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1280 - accuracy: 0.0000e+00
# Epoch 72/80
# 40/40 [==============================] - 0s 450us/step - loss: 0.1273 - accuracy: 0.0000e+00
# Epoch 73/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1268 - accuracy: 0.0000e+00
# Epoch 74/80
# 40/40 [==============================] - 0s 400us/step - loss: 0.1262 - accuracy: 0.0000e+00
# Epoch 75/80
# 40/40 [==============================] - 0s 475us/step - loss: 0.1255 - accuracy: 0.0000e+00
# Epoch 76/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1249 - accuracy: 0.0000e+00
# Epoch 77/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1243 - accuracy: 0.0000e+00
# Epoch 78/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1237 - accuracy: 0.0000e+00
# Epoch 79/80
# 40/40 [==============================] - 0s 375us/step - loss: 0.1234 - accuracy: 0.0000e+00
# Epoch 80/80
# 40/40 [==============================] - 0s 350us/step - loss: 0.1229 - accuracy: 0.0000e+00

# %% [markdown]
# Строим прогноз на тестовом множестве.

# %%
# Predicting the Test set results
y_pred = rnn.predict(X_test)

# %% [markdown]
# Осуществляем обратное шкалирование

# %%
# Inversing scaling
#yhat = pd.DataFrame(yhat, columns=['yhat']) 
from sklearn.preprocessing import StandardScaler
y_hat = sc_y.inverse_transform(y_pred)
y_test = sc_y.inverse_transform(y_test)
X_test = sc_X.inverse_transform(X_test)

# %% [markdown]
# Вычмслим сумму квадратов ошибок на тестовом множестве.

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_test, y_hat))
# Out:
# 9388.73279669805

# %% [markdown]
# Видим, что MSE в модели нейронной сети (9388.33) возрастает по сравнения с моделью регрессии (4043.018).

# %% [markdown]
# Построим график, на котором видно, что построенная модель нейронной сети сработала довольно четко по сравнению с многофакторной регрессией.

# %%
# Visualising the Test set results
plt.scatter(X_test[:,0], y_test, color = 'red')
plt.plot(X_test[:,0], y_hat, 'bo')
plt.title('Price vs Power (Test set)')
plt.xlabel('Power')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# В итоге имеем качественный результат работы НС, однако лучше с этими данными справилась простая многофакторная регрессия, возможно такие данные не требуют сложных архетиктур.
